# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\firda\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Pôvodné dáta (Jeden špekací pás)

# %%
data1 = pd.read_excel(r"C:\Users\firda\OneDrive\Študijný materiál\VŠ\2024 LS 2.rocnik\NeuronoveSiete\Zadanie\moje data\vysledny_dataset.xlsx", sheet_name="Sheet1")

X_data1 = data1.drop(columns=["Rozsev 0-5"])
y_data1 = data1["Rozsev 0-5"]

# %%
data1
# Out:
#      výstupné dáta  výstupné dáta.1  výstupné dáta.2  \
# 0        18.245233       708.250231        26.974017
# 1        17.924417       718.155392        31.431067
# 2        19.169966       709.452829       161.962400
# 3        18.356667       709.410084        61.538550
# 4        18.993284       715.636641        78.977666
# ..             ...              ...              ...
# 496      18.816999       710.190049        81.033282
# 497      18.816999       706.556821        72.524867
# 498      18.816999       695.341931        64.947766
# 499      18.816999       707.283079        77.876267
# 500      18.816999       707.584498        80.058234
#
#      vstupné dáta, reguluje palič  vstupné dáta, reguluje palič.1  \
# 0                      227.713533                        3.771100
# 1                      227.747202                        3.567233
# 2                      226.832703                        3.276133
# ...

# %%
# Distribucia dát pre Rozsev 0-5 na pôvodných dátach
sns.histplot(y_data1, kde=True, color='blue', bins=30)
plt.title('Distribution of Rozsev 0-5')
plt.xlabel('Rozsev 0-5 Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
data1.describe()
# Out:
#        výstupné dáta  výstupné dáta.1  výstupné dáta.2  \
# count     501.000000       501.000000       501.000000
# mean       18.798319       678.008646        87.607671
# std         0.273181        63.037892       443.399110
# min        17.586133         0.997033         1.347250
# 25%        18.816999       665.291565        44.123150
# 50%        18.816999       691.516441        60.027017
# 75%        18.816999       716.916610        83.098350
# max        20.930501       719.835356      9945.183140
#
#        vstupné dáta, reguluje palič  vstupné dáta, reguluje palič.1  \
# count                    501.000000                      501.000000
# mean                     194.493243                        2.257025
# std                       53.452576                        1.186228
# min                        0.000000                        0.000000
# 25%                      187.859483                        1.682450
# ...

# %% [markdown]
# Nove dáta (4 pásy 4 roky)

# %%
data2 = pd.read_excel(r"C:\Users\firda\OneDrive\Študijný materiál\VŠ\2024 LS 2.rocnik\NeuronoveSiete\Zadanie\modely\dataset_input.xlsx", sheet_name="Sheet1")

X_data2 = data2.drop(columns=["Rozsev5mm"])
y_data2 = data2["Rozsev5mm"]

# %%
data2
# Out:
#       výstupné dáta  výstupné dáta.1  výstupné dáta.2  \
# 0         18.250492       689.031586       128.623250
# 1         17.908492       668.094070        55.209067
# 2         17.960808       660.080982       106.115717
# 3         18.151758       590.895209        87.906391
# 4         18.245967       677.744265       112.744958
# ...             ...              ...              ...
# 9848      18.816999         0.000000         0.000000
# 9849      18.816999         0.000000         0.000000
# 9850      18.816999         0.000000         0.000000
# 9851      18.816999         0.000000         0.000000
# 9852      18.816999         0.000000         0.000000
#
#       vstupné dáta, reguluje palič  vstupné dáta, reguluje palič.1  \
# 0                        92.395000                        1.410808
# 1                       124.684634                        2.534675
# 2                       199.740409                        3.375942
# ...

# %%
# Distribucia dát pre Rozsev 0-5 na nových dátach
sns.histplot(y_data2, kde=True, color='blue', bins=30)
plt.title('Distribution of Rozsev 0-5')
plt.xlabel('Rozsev 0-5 Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
data2.describe()
# Out:
#        výstupné dáta  výstupné dáta.1  výstupné dáta.2  \
# count    9853.000000      9853.000000      9853.000000
# mean       18.307264       589.937203        83.413868
# std         1.377888       160.378844       436.089440
# min         0.000000         0.000000      -489.637240
# 25%        17.981959       502.216993        44.950284
# 50%        18.343984       629.622133        69.147784
# 75%        18.692658       713.146423        98.161675
# max        24.997999       899.945007     40244.733103
#
#        vstupné dáta, reguluje palič  vstupné dáta, reguluje palič.1  \
# count                   9853.000000                     9853.000000
# mean                     194.791706                        1.367973
# std                       51.321237                        1.408977
# min                        0.000000                       -0.005750
# 25%                      187.608783                        0.000000
# ...
